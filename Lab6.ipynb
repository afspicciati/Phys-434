# %% [markdown]
# # Lab 6 - Phys 434
# ## Andrew Spicciati
# ## 11/16/21

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import scipy
from scipy import stats

import pickle

plt.rcParams["figure.figsize"] = (15,8)

# %% [markdown]
# # Problem 1

# %%
x = np.linspace(0,200,201)
bkgd = stats.poisson.pmf(x,mu=100)

# %%
plt.step(x,bkgd,where='mid')

# %%
prob = stats.norm.cdf(5)

stats.poisson.ppf(prob,mu=100)
# Out:
# 154.0

# %%
bkgd = stats.poisson.rvs(mu=100,size=1000000)

# %%
plt.hist(bkgd)
# Out:
# (array([7.20000e+01, 3.90700e+03, 5.39420e+04, 2.37737e+05, 3.46126e+05,
#         2.66963e+05, 7.98630e+04, 1.07070e+04, 6.62000e+02, 2.10000e+01]),
#  array([ 55. ,  64.8,  74.6,  84.4,  94.2, 104. , 113.8, 123.6, 133.4,
#         143.2, 153. ]),
#  <BarContainer object of 10 artists>)

# %%
#10 sigma value to add signal

200 - stats.poisson.ppf(stats.norm.sf(10),mu=100)
# Out:
# 181.0

# %%
signal_size = 1000
signal = [0]*(1000000-signal_size)
for i in range(signal_size):
    signal.append(181)

# %%
data = signal + bkgd
plt.hist(data,bins=50)
plt.yscale('log')
